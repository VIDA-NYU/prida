# %%
# %%bash
#
# cd ../improvement-prediction
#
# if test -f /Users/fchirigati/projects/dataset-ranking/use-cases/data/training-records-features; then
#     rm /Users/fchirigati/projects/dataset-ranking/use-cases/data/training-records-features
# fi
#
# cat > .params_feature_generation.json << EOL
# {
#     "learning_data_filename": "/Users/fchirigati/projects/dataset-ranking/use-cases/data/training-records",
#     "augmentation_learning_data_filename": "/Users/fchirigati/projects/dataset-ranking/use-cases/data/training-records-features",
#     "file_dir": "data/",
#     "cluster": false,
#     "hdfs_address": "http://gray01.poly.edu:50070",
#     "hdfs_user": "fsc234"
# }
# EOL
#
# ./run-spark-client
# Out:
#   adding: augmentation_instance.py (deflated 80%)
#   adding: compare_training_and_test_distributions.py (deflated 68%)
#   adding: constants.py (deflated 71%)
#   adding: dataset.py (deflated 70%)
#   adding: feature_factory.py (deflated 83%)
#   adding: filter-training-and-test-data-given-features.py (deflated 65%)
#   adding: filter-training-and-test-data.py (deflated 63%)
#   adding: generate_data_for_augmentation_learning.py (deflated 64%)
#   adding: generate_data_for_augmentation_learning_spark.py (deflated 70%)
#   adding: learn_to_augment.py (deflated 57%)
#   adding: learning_task.py (deflated 79%)
#   adding: recommend_datasets.py (deflated 61%)
#   adding: recommender.py (deflated 79%)
#   adding: util/ (stored 0%)
#   adding: util/metrics.py (deflated 75%)
#   adding: util/misc.py (deflated 54%)
#   adding: util/feature_selection.py (deflated 62%)
#   adding: util/instance_parser.py (deflated 69%)
#   adding: util/__pycache__/ (stored 0%)
#   adding: util/__pycache__/instance_parser.cpython-37.pyc (deflated 51%)
#   adding: util/__pycache__/file_manager.cpython-37.pyc (deflated 46%)
#   adding: util/__pycache__/metrics.cpython-37.pyc (deflated 65%)
#   adding: util/__pycache__/misc.cpython-37.pyc (deflated 30%)
#   adding: util/debug.py (deflated 75%)
#   adding: util/graphic_functions.py (deflated 52%)
#   adding: util/file_manager.py (deflated 70%)
# [INFO] File /Users/fchirigati/projects/dataset-ranking/use-cases/data/training-records-features saved!
# Duration: 32.7518 seconds
# 20/02/08 18:43:31 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# 20/02/08 18:43:34 INFO SparkContext: Running Spark version 2.4.4
# 20/02/08 18:43:35 INFO SparkContext: Submitted application: Feature Generation
# 20/02/08 18:43:35 INFO SecurityManager: Changing view acls to: fchirigati
# 20/02/08 18:43:35 INFO SecurityManager: Changing modify acls to: fchirigati
# 20/02/08 18:43:35 INFO SecurityManager: Changing view acls groups to:
# 20/02/08 18:43:35 INFO SecurityManager: Changing modify acls groups to:
# 20/02/08 18:43:35 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(fchirigati); groups with view permissions: Set(); users  with modify permissions: Set(fchirigati); groups with modify permissions: Set()
# 20/02/08 18:43:35 INFO Utils: Successfully started service 'sparkDriver' on port 64045.
# 20/02/08 18:43:35 INFO SparkEnv: Registering MapOutputTracker
# 20/02/08 18:43:35 INFO SparkEnv: Registering BlockManagerMaster
# 20/02/08 18:43:35 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 20/02/08 18:43:35 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 20/02/08 18:43:35 INFO DiskBlockManager: Created local directory at /private/var/folders/2m/l7l9md295llfp5dvnqrwvydh0000gn/T/blockmgr-7aa3d19a-7397-44b3-9597-d0d14b246cd5
# 20/02/08 18:43:35 INFO MemoryStore: MemoryStore started with capacity 366.3 MB
# 20/02/08 18:43:35 INFO SparkEnv: Registering OutputCommitCoordinator
# 20/02/08 18:43:35 INFO Utils: Successfully started service 'SparkUI' on port 4040.
# 20/02/08 18:43:35 INFO SparkUI: Bound SparkUI to 0.0.0.0, and started at http://mctest1.shc.sa.nyu.edu:4040
# 20/02/08 18:43:35 INFO SparkContext: Added file file:///Users/fchirigati/projects/dataset-ranking/improvement-prediction/.params_feature_generation.json at file:///Users/fchirigati/projects/dataset-ranking/improvement-prediction/.params_feature_generation.json with timestamp 1581205415719
# 20/02/08 18:43:35 INFO Utils: Copying /Users/fchirigati/projects/dataset-ranking/improvement-prediction/.params_feature_generation.json to /private/var/folders/2m/l7l9md295llfp5dvnqrwvydh0000gn/T/spark-dd678374-ef57-427e-be5c-163cf91598fd/userFiles-325ea1a9-c023-422c-83d4-e37f0fd88524/.params_feature_generation.json
# 20/02/08 18:43:35 INFO Executor: Starting executor ID driver on host localhost
# 20/02/08 18:43:35 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 64046.
# 20/02/08 18:43:35 INFO NettyBlockTransferService: Server created on mctest1.shc.sa.nyu.edu:64046
# 20/02/08 18:43:35 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 20/02/08 18:43:35 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, mctest1.shc.sa.nyu.edu, 64046, None)
# 20/02/08 18:43:36 INFO BlockManagerMasterEndpoint: Registering block manager mctest1.shc.sa.nyu.edu:64046 with 366.3 MB RAM, BlockManagerId(driver, mctest1.shc.sa.nyu.edu, 64046, None)
# 20/02/08 18:43:36 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, mctest1.shc.sa.nyu.edu, 64046, None)
# 20/02/08 18:43:36 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, mctest1.shc.sa.nyu.edu, 64046, None)
# 20/02/08 18:43:36 INFO MemoryStore: Block broadcast_0 stored as values in memory (estimated size 236.7 KB, free 366.1 MB)
# 20/02/08 18:43:37 INFO MemoryStore: Block broadcast_0_piece0 stored as bytes in memory (estimated size 22.9 KB, free 366.0 MB)
# 20/02/08 18:43:37 INFO BlockManagerInfo: Added broadcast_0_piece0 in memory on mctest1.shc.sa.nyu.edu:64046 (size: 22.9 KB, free: 366.3 MB)
# 20/02/08 18:43:37 INFO SparkContext: Created broadcast 0 from textFile at NativeMethodAccessorImpl.java:0
# 20/02/08 18:43:37 INFO FileInputFormat: Total input paths to process : 1
# 20/02/08 18:43:37 INFO SparkContext: Starting job: collect at /Users/fchirigati/projects/dataset-ranking/improvement-prediction/generate_data_for_augmentation_learning_spark.py:87
# 20/02/08 18:43:37 INFO DAGScheduler: Got job 0 (collect at /Users/fchirigati/projects/dataset-ranking/improvement-prediction/generate_data_for_augmentation_learning_spark.py:87) with 2 output partitions
# 20/02/08 18:43:37 INFO DAGScheduler: Final stage: ResultStage 0 (collect at /Users/fchirigati/projects/dataset-ranking/improvement-prediction/generate_data_for_augmentation_learning_spark.py:87)
# 20/02/08 18:43:37 INFO DAGScheduler: Parents of final stage: List()
# 20/02/08 18:43:37 INFO DAGScheduler: Missing parents: List()
# 20/02/08 18:43:37 INFO DAGScheduler: Submitting ResultStage 0 (PythonRDD[2] at collect at /Users/fchirigati/projects/dataset-ranking/improvement-prediction/generate_data_for_augmentation_learning_spark.py:87), which has no missing parents
# 20/02/08 18:43:37 INFO MemoryStore: Block broadcast_1 stored as values in memory (estimated size 8.8 KB, free 366.0 MB)
# 20/02/08 18:43:37 INFO MemoryStore: Block broadcast_1_piece0 stored as bytes in memory (estimated size 5.6 KB, free 366.0 MB)
# 20/02/08 18:43:37 INFO BlockManagerInfo: Added broadcast_1_piece0 in memory on mctest1.shc.sa.nyu.edu:64046 (size: 5.6 KB, free: 366.3 MB)
# 20/02/08 18:43:37 INFO SparkContext: Created broadcast 1 from broadcast at DAGScheduler.scala:1161
# 20/02/08 18:43:37 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 0 (PythonRDD[2] at collect at /Users/fchirigati/projects/dataset-ranking/improvement-prediction/generate_data_for_augmentation_learning_spark.py:87) (first 15 tasks are for partitions Vector(0, 1))
# 20/02/08 18:43:37 INFO TaskSchedulerImpl: Adding task set 0.0 with 2 tasks
# 20/02/08 18:43:37 INFO TaskSetManager: Starting task 0.0 in stage 0.0 (TID 0, localhost, executor driver, partition 0, PROCESS_LOCAL, 7956 bytes)
# 20/02/08 18:43:37 INFO TaskSetManager: Starting task 1.0 in stage 0.0 (TID 1, localhost, executor driver, partition 1, PROCESS_LOCAL, 7956 bytes)
# 20/02/08 18:43:37 INFO Executor: Running task 1.0 in stage 0.0 (TID 1)
# 20/02/08 18:43:37 INFO Executor: Running task 0.0 in stage 0.0 (TID 0)
# 20/02/08 18:43:37 INFO Executor: Fetching file:///Users/fchirigati/projects/dataset-ranking/improvement-prediction/.params_feature_generation.json with timestamp 1581205415719
# 20/02/08 18:43:37 INFO Utils: /Users/fchirigati/projects/dataset-ranking/improvement-prediction/.params_feature_generation.json has been previously copied to /private/var/folders/2m/l7l9md295llfp5dvnqrwvydh0000gn/T/spark-dd678374-ef57-427e-be5c-163cf91598fd/userFiles-325ea1a9-c023-422c-83d4-e37f0fd88524/.params_feature_generation.json
# 20/02/08 18:43:37 INFO HadoopRDD: Input split: file:/Users/fchirigati/projects/dataset-ranking/use-cases/data/training-records/training-records:0+1416
# 20/02/08 18:43:37 INFO HadoopRDD: Input split: file:/Users/fchirigati/projects/dataset-ranking/use-cases/data/training-records/training-records:1416+1416
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# 20/02/08 18:43:42 INFO PythonRunner: Times: total = 4868, boot = 426, init = 1452, finish = 2990
# 20/02/08 18:43:42 INFO Executor: Finished task 1.0 in stage 0.0 (TID 1). 2905 bytes result sent to driver
# 20/02/08 18:43:42 INFO TaskSetManager: Finished task 1.0 in stage 0.0 (TID 1) in 5015 ms on localhost (executor driver) (1/2)
# 20/02/08 18:43:42 INFO PythonAccumulatorV2: Connected to AccumulatorServer at host: 127.0.0.1 port: 64047
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# 20/02/08 18:44:07 INFO PythonRunner: Times: total = 30189, boot = 422, init = 1449, finish = 28318
# 20/02/08 18:44:07 INFO Executor: Finished task 0.0 in stage 0.0 (TID 0). 2967 bytes result sent to driver
# 20/02/08 18:44:07 INFO TaskSetManager: Finished task 0.0 in stage 0.0 (TID 0) in 30326 ms on localhost (executor driver) (2/2)
# 20/02/08 18:44:07 INFO TaskSchedulerImpl: Removed TaskSet 0.0, whose tasks have all completed, from pool
# 20/02/08 18:44:07 INFO DAGScheduler: ResultStage 0 (collect at /Users/fchirigati/projects/dataset-ranking/improvement-prediction/generate_data_for_augmentation_learning_spark.py:87) finished in 30.375 s
# 20/02/08 18:44:07 INFO DAGScheduler: Job 0 finished: collect at /Users/fchirigati/projects/dataset-ranking/improvement-prediction/generate_data_for_augmentation_learning_spark.py:87, took 30.425787 s
# 20/02/08 18:44:07 INFO SparkContext: Invoking stop() from shutdown hook
# 20/02/08 18:44:07 INFO SparkUI: Stopped Spark web UI at http://mctest1.shc.sa.nyu.edu:4040
# 20/02/08 18:44:07 INFO MapOutputTrackerMasterEndpoint: MapOutputTrackerMasterEndpoint stopped!
# 20/02/08 18:44:07 INFO MemoryStore: MemoryStore cleared
# 20/02/08 18:44:07 INFO BlockManager: BlockManager stopped
# 20/02/08 18:44:07 INFO BlockManagerMaster: BlockManagerMaster stopped
# 20/02/08 18:44:07 INFO OutputCommitCoordinator$OutputCommitCoordinatorEndpoint: OutputCommitCoordinator stopped!
# 20/02/08 18:44:07 INFO SparkContext: Successfully stopped SparkContext
# 20/02/08 18:44:07 INFO ShutdownHookManager: Shutdown hook called
# 20/02/08 18:44:07 INFO ShutdownHookManager: Deleting directory /private/var/folders/2m/l7l9md295llfp5dvnqrwvydh0000gn/T/spark-dd678374-ef57-427e-be5c-163cf91598fd
# 20/02/08 18:44:07 INFO ShutdownHookManager: Deleting directory /private/var/folders/2m/l7l9md295llfp5dvnqrwvydh0000gn/T/spark-dd678374-ef57-427e-be5c-163cf91598fd/pyspark-fbfaaad9-09f8-4b2f-921e-8653c1bd37a5
# 20/02/08 18:44:07 INFO ShutdownHookManager: Deleting directory /private/var/folders/2m/l7l9md295llfp5dvnqrwvydh0000gn/T/spark-ac6fea97-8a0f-4b66-996f-a7a7a6f52381

# %%
import pandas as pd

features = pd.read_csv(
    '/Users/fchirigati/projects/dataset-ranking/use-cases/data/training-records-features',
    header=None,
    names=[
        'query',
        'target',
        'candidate',
        'query_num_of_columns',
        'query_num_of_rows',
        'query_row_column_ratio',
        'query_max_mean',
        'query_max_outlier_percentage',
        'query_max_skewness',
        'query_max_kurtosis',
        'query_max_unique',
        'candidate_num_of_columns',
        'candidate_num_rows',
        'candidate_row_column_ratio',
        'candidate_max_mean',
        'candidate_max_outlier_percentage',
        'candidate_max_skewness',
        'candidate_max_kurtosis',
        'candidate_max_unique',
        'query_target_max_pearson',
        'query_target_max_spearman',
        'query_target_max_covariance',
        'query_target_max_mutual_info',
        'candidate_target_max_pearson',
        'candidate_target_max_spearman',
        'candidate_target_max_covariance',
        'candidate_target_max_mutual_info',
        'max_pearson_difference',
        'containment_fraction',
        'decrease_in_mae',
        'decrease_in_mse',
        'decrease_in_medae',
        'gain_in_r2_score'
    ]
)
features.to_csv(
    '/Users/fchirigati/projects/dataset-ranking/use-cases/data/training-records-features',
    index=False
)
