# %%
# %%bash
#
# cd ../improvement-prediction
#
# rm /Users/fchirigati/projects/dataset-ranking/use-cases/data/training-records-features
# cat > .params_feature_generation.json << EOL
# {
#     "learning_data_filename": "/Users/fchirigati/projects/dataset-ranking/use-cases/data/training-records",
#     "augmentation_learning_data_filename": "/Users/fchirigati/projects/dataset-ranking/use-cases/data/training-records-features",
#     "cluster": false,
#     "hdfs_address": "http://gray01.poly.edu:50070",
#     "hdfs_user": "fsc234"
# }
# EOL
#
# ./run-spark-client
# Out:
#   adding: augmentation_instance.py (deflated 79%)
#   adding: compare_training_and_test_distributions.py (deflated 68%)
#   adding: constants.py (deflated 71%)
#   adding: dataset.py (deflated 69%)
#   adding: feature_factory.py (deflated 83%)
#   adding: filter-training-and-test-data-given-features.py (deflated 65%)
#   adding: filter-training-and-test-data.py (deflated 63%)
#   adding: generate_data_for_augmentation_learning.py (deflated 64%)
#   adding: generate_data_for_augmentation_learning_spark.py (deflated 70%)
#   adding: learn_to_augment.py (deflated 57%)
#   adding: learning_task.py (deflated 79%)
#   adding: recommend_datasets.py (deflated 61%)
#   adding: recommender.py (deflated 79%)
#   adding: util/ (stored 0%)
#   adding: util/metrics.py (deflated 75%)
#   adding: util/misc.py (deflated 54%)
#   adding: util/feature_selection.py (deflated 62%)
#   adding: util/instance_parser.py (deflated 67%)
#   adding: util/__pycache__/ (stored 0%)
#   adding: util/__pycache__/instance_parser.cpython-37.pyc (deflated 51%)
#   adding: util/__pycache__/file_manager.cpython-37.pyc (deflated 46%)
#   adding: util/__pycache__/metrics.cpython-37.pyc (deflated 65%)
#   adding: util/__pycache__/misc.cpython-37.pyc (deflated 30%)
#   adding: util/debug.py (deflated 75%)
#   adding: util/graphic_functions.py (deflated 52%)
#   adding: util/file_manager.py (deflated 70%)
# [WARNING] File already exists: /Users/fchirigati/projects/dataset-ranking/use-cases/data/training-records-features
# [INFO] File /Users/fchirigati/projects/dataset-ranking/use-cases/data/training-records-features saved!
# Duration: 6.0819 seconds
# 20/02/05 10:50:38 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# 20/02/05 10:50:40 INFO SparkContext: Running Spark version 2.4.4
# 20/02/05 10:50:40 INFO SparkContext: Submitted application: Feature Generation
# 20/02/05 10:50:40 INFO SecurityManager: Changing view acls to: fchirigati
# 20/02/05 10:50:40 INFO SecurityManager: Changing modify acls to: fchirigati
# 20/02/05 10:50:40 INFO SecurityManager: Changing view acls groups to:
# 20/02/05 10:50:40 INFO SecurityManager: Changing modify acls groups to:
# 20/02/05 10:50:40 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(fchirigati); groups with view permissions: Set(); users  with modify permissions: Set(fchirigati); groups with modify permissions: Set()
# 20/02/05 10:50:40 INFO Utils: Successfully started service 'sparkDriver' on port 64853.
# 20/02/05 10:50:40 INFO SparkEnv: Registering MapOutputTracker
# 20/02/05 10:50:41 INFO SparkEnv: Registering BlockManagerMaster
# 20/02/05 10:50:41 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 20/02/05 10:50:41 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 20/02/05 10:50:41 INFO DiskBlockManager: Created local directory at /private/var/folders/2m/l7l9md295llfp5dvnqrwvydh0000gn/T/blockmgr-59a1094e-be0d-4d49-a5fd-c24c737b01cc
# 20/02/05 10:50:41 INFO MemoryStore: MemoryStore started with capacity 366.3 MB
# 20/02/05 10:50:41 INFO SparkEnv: Registering OutputCommitCoordinator
# 20/02/05 10:50:41 INFO Utils: Successfully started service 'SparkUI' on port 4040.
# 20/02/05 10:50:41 INFO SparkUI: Bound SparkUI to 0.0.0.0, and started at http://10-18-217-16.dynapool.wireless.nyu.edu:4040
# 20/02/05 10:50:41 INFO SparkContext: Added file file:///Users/fchirigati/projects/dataset-ranking/improvement-prediction/.params_feature_generation.json at file:///Users/fchirigati/projects/dataset-ranking/improvement-prediction/.params_feature_generation.json with timestamp 1580917841283
# 20/02/05 10:50:41 INFO Utils: Copying /Users/fchirigati/projects/dataset-ranking/improvement-prediction/.params_feature_generation.json to /private/var/folders/2m/l7l9md295llfp5dvnqrwvydh0000gn/T/spark-3490964c-2f14-41a3-b918-d4ebc4f470ba/userFiles-7d756dab-d817-4087-8200-75329efc8028/.params_feature_generation.json
# 20/02/05 10:50:41 INFO Executor: Starting executor ID driver on host localhost
# 20/02/05 10:50:41 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 64854.
# 20/02/05 10:50:41 INFO NettyBlockTransferService: Server created on 10-18-217-16.dynapool.wireless.nyu.edu:64854
# 20/02/05 10:50:41 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 20/02/05 10:50:41 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 10-18-217-16.dynapool.wireless.nyu.edu, 64854, None)
# 20/02/05 10:50:41 INFO BlockManagerMasterEndpoint: Registering block manager 10-18-217-16.dynapool.wireless.nyu.edu:64854 with 366.3 MB RAM, BlockManagerId(driver, 10-18-217-16.dynapool.wireless.nyu.edu, 64854, None)
# 20/02/05 10:50:41 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 10-18-217-16.dynapool.wireless.nyu.edu, 64854, None)
# 20/02/05 10:50:41 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, 10-18-217-16.dynapool.wireless.nyu.edu, 64854, None)
# 20/02/05 10:50:41 INFO MemoryStore: Block broadcast_0 stored as values in memory (estimated size 236.7 KB, free 366.1 MB)
# 20/02/05 10:50:42 INFO MemoryStore: Block broadcast_0_piece0 stored as bytes in memory (estimated size 22.9 KB, free 366.0 MB)
# 20/02/05 10:50:42 INFO BlockManagerInfo: Added broadcast_0_piece0 in memory on 10-18-217-16.dynapool.wireless.nyu.edu:64854 (size: 22.9 KB, free: 366.3 MB)
# 20/02/05 10:50:42 INFO SparkContext: Created broadcast 0 from textFile at NativeMethodAccessorImpl.java:0
# 20/02/05 10:50:42 INFO FileInputFormat: Total input paths to process : 1
# 20/02/05 10:50:42 INFO SparkContext: Starting job: collect at /Users/fchirigati/projects/dataset-ranking/improvement-prediction/generate_data_for_augmentation_learning_spark.py:86
# 20/02/05 10:50:42 INFO DAGScheduler: Got job 0 (collect at /Users/fchirigati/projects/dataset-ranking/improvement-prediction/generate_data_for_augmentation_learning_spark.py:86) with 2 output partitions
# 20/02/05 10:50:42 INFO DAGScheduler: Final stage: ResultStage 0 (collect at /Users/fchirigati/projects/dataset-ranking/improvement-prediction/generate_data_for_augmentation_learning_spark.py:86)
# 20/02/05 10:50:42 INFO DAGScheduler: Parents of final stage: List()
# 20/02/05 10:50:42 INFO DAGScheduler: Missing parents: List()
# 20/02/05 10:50:42 INFO DAGScheduler: Submitting ResultStage 0 (PythonRDD[2] at collect at /Users/fchirigati/projects/dataset-ranking/improvement-prediction/generate_data_for_augmentation_learning_spark.py:86), which has no missing parents
# 20/02/05 10:50:42 INFO MemoryStore: Block broadcast_1 stored as values in memory (estimated size 8.8 KB, free 366.0 MB)
# 20/02/05 10:50:42 INFO MemoryStore: Block broadcast_1_piece0 stored as bytes in memory (estimated size 5.6 KB, free 366.0 MB)
# 20/02/05 10:50:42 INFO BlockManagerInfo: Added broadcast_1_piece0 in memory on 10-18-217-16.dynapool.wireless.nyu.edu:64854 (size: 5.6 KB, free: 366.3 MB)
# 20/02/05 10:50:42 INFO SparkContext: Created broadcast 1 from broadcast at DAGScheduler.scala:1161
# 20/02/05 10:50:42 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 0 (PythonRDD[2] at collect at /Users/fchirigati/projects/dataset-ranking/improvement-prediction/generate_data_for_augmentation_learning_spark.py:86) (first 15 tasks are for partitions Vector(0, 1))
# 20/02/05 10:50:42 INFO TaskSchedulerImpl: Adding task set 0.0 with 2 tasks
# 20/02/05 10:50:42 INFO TaskSetManager: Starting task 0.0 in stage 0.0 (TID 0, localhost, executor driver, partition 0, PROCESS_LOCAL, 7956 bytes)
# 20/02/05 10:50:42 INFO TaskSetManager: Starting task 1.0 in stage 0.0 (TID 1, localhost, executor driver, partition 1, PROCESS_LOCAL, 7956 bytes)
# 20/02/05 10:50:42 INFO Executor: Running task 1.0 in stage 0.0 (TID 1)
# 20/02/05 10:50:42 INFO Executor: Running task 0.0 in stage 0.0 (TID 0)
# 20/02/05 10:50:42 INFO Executor: Fetching file:///Users/fchirigati/projects/dataset-ranking/improvement-prediction/.params_feature_generation.json with timestamp 1580917841283
# 20/02/05 10:50:42 INFO Utils: /Users/fchirigati/projects/dataset-ranking/improvement-prediction/.params_feature_generation.json has been previously copied to /private/var/folders/2m/l7l9md295llfp5dvnqrwvydh0000gn/T/spark-3490964c-2f14-41a3-b918-d4ebc4f470ba/userFiles-7d756dab-d817-4087-8200-75329efc8028/.params_feature_generation.json
# 20/02/05 10:50:42 INFO HadoopRDD: Input split: file:/Users/fchirigati/projects/dataset-ranking/use-cases/data/training-records/training-records:833+833
# 20/02/05 10:50:42 INFO HadoopRDD: Input split: file:/Users/fchirigati/projects/dataset-ranking/use-cases/data/training-records/training-records:0+833
# FILENAME /Users/fchirigati/projects/dataset-ranking/use-cases/data/taxi-vehicle-collision/taxi-vehicle-collision-v2.csv
# FILENAME /Users/fchirigati/projects/dataset-ranking/use-cases/data/poverty-estimation/poverty-estimation-v2.csv
# FILENAME /Users/fchirigati/projects/dataset-ranking/use-cases/data/taxi-vehicle-collision/weather-v2.csv
# FILENAME /Users/fchirigati/projects/dataset-ranking/use-cases/data/poverty-estimation/population-unemployment.csv
# names of columns before Index(['n. trips', 'n. collisions'], dtype='object') and Index(['Amt[PrecipHourly1]', 'Temp[Temp]', 'Visby[Visibility]'], dtype='object')
# names of columns after Index(['n. trips', 'n. collisions', 'Amt[PrecipHourly1]', 'Temp[Temp]',
#        'Visby[Visibility]'],
#       dtype='object')
# names of columns before Index(['RUCCode', 'POVALL_2016'], dtype='object') and Index(['Rural-urban_Continuum Code_2003', 'Rural-urban_Continuum Code_2013',
#        'Urban_Influence_Code_2003', 'Urban_Influence_Code_2013',
#        'Economic_typology_2015', 'RESIDUAL_2016', 'R_birth_2011',
#        'R_birth_2012', 'R_birth_2013', 'R_birth_2014', 'R_birth_2015',
#        'R_birth_2016', 'R_death_2011', 'R_death_2012', 'R_death_2013',
#        'R_death_2014', 'R_death_2015', 'R_death_2016', 'R_NATURAL_INC_2011',
#        'R_NATURAL_INC_2012', 'R_NATURAL_INC_2013', 'R_NATURAL_INC_2014',
#        'R_NATURAL_INC_2015', 'R_NATURAL_INC_2016', 'R_INTERNATIONAL_MIG_2011',
#        'R_INTERNATIONAL_MIG_2012', 'R_INTERNATIONAL_MIG_2013',
#        'R_INTERNATIONAL_MIG_2014', 'R_INTERNATIONAL_MIG_2015',
#        'R_INTERNATIONAL_MIG_2016', 'R_DOMESTIC_MIG_2011',
#        'R_DOMESTIC_MIG_2012', 'R_DOMESTIC_MIG_2013', 'R_DOMESTIC_MIG_2014',
#        'R_DOMESTIC_MIG_2015', 'R_DOMESTIC_MIG_2016', 'R_NET_MIG_2011',
#        'R_NET_MIG_2012', 'R_NET_MIG_2013', 'R_NET_MIG_2014', 'R_NET_MIG_2015',
#        'R_NET_MIG_2016', 'Rural_urban_continuum_code_2013', 'Metro_2013',
#        'Unemployment_rate_2007', 'Unemployment_rate_2008',
#        'Unemployment_rate_2009', 'Unemployment_rate_2010',
#        'Unemployment_rate_2011', 'Unemployment_rate_2012',
#        'Unemployment_rate_2013', 'Unemployment_rate_2014',
#        'Unemployment_rate_2015', 'Unemployment_rate_2016'],
#       dtype='object')
# names of columns after Index(['RUCCode', 'POVALL_2016', 'Rural-urban_Continuum Code_2003',
#        'Rural-urban_Continuum Code_2013', 'Urban_Influence_Code_2003',
#        'Urban_Influence_Code_2013', 'Economic_typology_2015', 'RESIDUAL_2016',
#        'R_birth_2011', 'R_birth_2012', 'R_birth_2013', 'R_birth_2014',
#        'R_birth_2015', 'R_birth_2016', 'R_death_2011', 'R_death_2012',
#        'R_death_2013', 'R_death_2014', 'R_death_2015', 'R_death_2016',
#        'R_NATURAL_INC_2011', 'R_NATURAL_INC_2012', 'R_NATURAL_INC_2013',
#        'R_NATURAL_INC_2014', 'R_NATURAL_INC_2015', 'R_NATURAL_INC_2016',
#        'R_INTERNATIONAL_MIG_2011', 'R_INTERNATIONAL_MIG_2012',
#        'R_INTERNATIONAL_MIG_2013', 'R_INTERNATIONAL_MIG_2014',
#        'R_INTERNATIONAL_MIG_2015', 'R_INTERNATIONAL_MIG_2016',
#        'R_DOMESTIC_MIG_2011', 'R_DOMESTIC_MIG_2012', 'R_DOMESTIC_MIG_2013',
#        'R_DOMESTIC_MIG_2014', 'R_DOMESTIC_MIG_2015', 'R_DOMESTIC_MIG_2016',
#        'R_NET_MIG_2011', 'R_NET_MIG_2012', 'R_NET_MIG_2013', 'R_NET_MIG_2014',
#        'R_NET_MIG_2015', 'R_NET_MIG_2016', 'Rural_urban_continuum_code_2013',
#        'Metro_2013', 'Unemployment_rate_2007', 'Unemployment_rate_2008',
#        'Unemployment_rate_2009', 'Unemployment_rate_2010',
#        'Unemployment_rate_2011', 'Unemployment_rate_2012',
#        'Unemployment_rate_2013', 'Unemployment_rate_2014',
#        'Unemployment_rate_2015', 'Unemployment_rate_2016'],
#       dtype='object')
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# FILENAME /Users/fchirigati/projects/dataset-ranking/use-cases/data/college-debt/college-debt-v2.csv
# FILENAME /Users/fchirigati/projects/dataset-ranking/use-cases/data/college-debt/college-scorecard-v2.csv
# names of columns before Index(['PCTFLOAN', 'CONTROL', 'PCIP16', 'PPTUG_EF', 'UGDS_WHITE', 'UGDS_BLACK',
#        'UGDS_HISP', 'UGDS_ASIAN', 'SATMTMID', 'SATVRMID', 'SATWRMID', 'UGDS',
#        'PREDDEG', 'DEBT_EARNINGS_RATIO'],
#       dtype='object') and Index(['OPEID', 'OPEID6', 'HCM2', 'PREDDEG', 'LOCALE', 'CONTROL', 'HBCU',
#        'PBI', 'ANNHI', 'TRIBAL',
#        ...
#        'NPT43_PRIV', 'NPT44_PRIV', 'NPT45_PRIV', 'PCTPELL', 'RET_FT4',
#        'RET_FTL4', 'RET_PT4', 'RET_PTL4', 'PCTFLOAN', 'UG25ABV'],
#       dtype='object', length=109)
# names of columns after Index(['PCTFLOAN_left', 'CONTROL_left', 'PCIP16_left', 'PPTUG_EF_left',
#        'UGDS_WHITE_left', 'UGDS_BLACK_left', 'UGDS_HISP_left',
#        'UGDS_ASIAN_left', 'SATMTMID_left', 'SATVRMID_left',
#        ...
#        'NPT43_PRIV', 'NPT44_PRIV', 'NPT45_PRIV', 'PCTPELL', 'RET_FT4',
#        'RET_FTL4', 'RET_PT4', 'RET_PTL4', 'PCTFLOAN', 'UG25ABV'],
#       dtype='object', length=123)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# 20/02/05 10:50:45 INFO PythonRunner: Times: total = 2608, boot = 372, init = 1510, finish = 726
# 20/02/05 10:50:45 INFO Executor: Finished task 1.0 in stage 0.0 (TID 1). 2228 bytes result sent to driver
# 20/02/05 10:50:45 INFO TaskSetManager: Finished task 1.0 in stage 0.0 (TID 1) in 2730 ms on localhost (executor driver) (1/2)
# 20/02/05 10:50:45 INFO PythonAccumulatorV2: Connected to AccumulatorServer at host: 127.0.0.1 port: 64855
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:859: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# 20/02/05 10:50:46 INFO PythonRunner: Times: total = 4227, boot = 368, init = 1512, finish = 2347
# 20/02/05 10:50:46 INFO Executor: Finished task 0.0 in stage 0.0 (TID 0). 2929 bytes result sent to driver
# 20/02/05 10:50:46 INFO TaskSetManager: Finished task 0.0 in stage 0.0 (TID 0) in 4345 ms on localhost (executor driver) (2/2)
# 20/02/05 10:50:46 INFO TaskSchedulerImpl: Removed TaskSet 0.0, whose tasks have all completed, from pool
# 20/02/05 10:50:46 INFO DAGScheduler: ResultStage 0 (collect at /Users/fchirigati/projects/dataset-ranking/improvement-prediction/generate_data_for_augmentation_learning_spark.py:86) finished in 4.393 s
# 20/02/05 10:50:46 INFO DAGScheduler: Job 0 finished: collect at /Users/fchirigati/projects/dataset-ranking/improvement-prediction/generate_data_for_augmentation_learning_spark.py:86, took 4.440653 s
# 20/02/05 10:50:46 INFO SparkContext: Invoking stop() from shutdown hook
# 20/02/05 10:50:46 INFO SparkUI: Stopped Spark web UI at http://10-18-217-16.dynapool.wireless.nyu.edu:4040
# 20/02/05 10:50:46 INFO MapOutputTrackerMasterEndpoint: MapOutputTrackerMasterEndpoint stopped!
# 20/02/05 10:50:46 INFO MemoryStore: MemoryStore cleared
# 20/02/05 10:50:46 INFO BlockManager: BlockManager stopped
# 20/02/05 10:50:46 INFO BlockManagerMaster: BlockManagerMaster stopped
# 20/02/05 10:50:46 INFO OutputCommitCoordinator$OutputCommitCoordinatorEndpoint: OutputCommitCoordinator stopped!
# 20/02/05 10:50:46 INFO SparkContext: Successfully stopped SparkContext
# 20/02/05 10:50:46 INFO ShutdownHookManager: Shutdown hook called
# 20/02/05 10:50:46 INFO ShutdownHookManager: Deleting directory /private/var/folders/2m/l7l9md295llfp5dvnqrwvydh0000gn/T/spark-3490964c-2f14-41a3-b918-d4ebc4f470ba/pyspark-f9724bc9-d6bf-499b-81d7-05b1e3163177
# 20/02/05 10:50:46 INFO ShutdownHookManager: Deleting directory /private/var/folders/2m/l7l9md295llfp5dvnqrwvydh0000gn/T/spark-3490964c-2f14-41a3-b918-d4ebc4f470ba
# 20/02/05 10:50:46 INFO ShutdownHookManager: Deleting directory /private/var/folders/2m/l7l9md295llfp5dvnqrwvydh0000gn/T/spark-686d5be4-01cf-4a1d-a261-ce4b4ef84abb
